# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
numbers=[10,3,4,7,9,10,5,3,8]

# %%
numbers=[10,3,4,7,9,10,5,3,8]

# %%
plt.plot(numbers);

# %%
x=[1,2,3,4,5,6,7,8,2,1]
y=[1,2,3,4,5,6,7,8,2,1]
z=[15,20,40,50,60,90,100,12,25,46]

# %%
plt.plot(x,y);

# %%
plt.plot(x,y)
plt.xlabel('x')
plt.ylabel('y');

# %%
plt.plot(x,y)
plt.xlabel('')
plt.ylabel('');

# %%
plt.plot(name, x)
plt.plot(name, y)
plt.xlabel('x')
plt.ylabel('y');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 plt.plot(name, x)
#       2 plt.plot(name, y)
#       3 plt.xlabel('x')
#
# NameError: name 'name' is not defined

# %%
plt.plot(x,y, marker='s' ,c='b' ,ls='-', lw=2, ms=8, mew=2, mec='navy')
plt.plot(x,y, marker='o', ls='-',lw='3' ,ms=10, alpha=.5 )

plt.xlabel('x')
plt.ylabel('y')
    
plt.title(['x'])
plt.legend(['y']);

# %%
plt.plot(x,y, marker='D' ,c='k' ,ls='--', lw=2, ms=8, mew=2, mec='navy')

plt.plot(x,y, marker='o', ls='-',lw='3' ,ms=10, alpha=.5 )

plt.xlabel('x')
plt.ylabel('y')
    
plt.title(['z'])
plt.legend(['y']);

# %%
plt.plot(x,y, marker='D' ,c='k' ,ls='--', lw=2, ms=8, mew=2, mec='navy')

plt.plot(x,z, marker='o', ls='-',lw='3' ,ms=10, alpha=.5 )

plt.xlabel('x')
plt.ylabel('y')
    
plt.title(['z'])
plt.legend(['y']);

# %%
plt.plot(name,x,'s-b')
plt.plot(name,y,'o--r')

plt.title("x")
plt.legend(x,)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 plt.plot(name,x,'s-b')
#       2 plt.plot(name,y,'o--r')
#       4 plt.title("x")
#
# NameError: name 'name' is not defined

# %%
sns.set_style("darkgrid")

# %%
plt.plot(x,y, 's-b')
plt.plot(x,y, 'o--r')

plt.xlabel('x')
plt.ylabel('y')

plt.title('x')
plt.legend('y');

# %%
sns.load_dataset("iris")
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
flowers_df=sns.load_dataset("iris")

# %%
flowers_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
flowers_df.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
plt.plot(flowers_df.sepal_length,flowers_df.sepal_width)

# %%
sns.scatterplot(x=flowers_df.sepal_length,y=flowers_df.sepal_width);

# %%
sns.scatterplot(x=flowers_df.sepal_length,y=flowers_df.sepal_width,hue=flowers_df.species,s=300);

# %%
plt.title('Sepal Dimension')
sns.scatterplot(x='sepal_length',
                y='sepal_width',
                hue='species',
               s=300,
              data=flowers_df );

# %%
plt.title("SUDHARSAN")
plt.hist(flowers_df.sepal_length);

# %%
plt.hist(flowers_df.sepal_width,bins=10);

# %%
import numpy as np

# %%
plt.hist(flowers_df.petal_width,bins=np.arange(2,5,0.25));

# %%
plt.hist(flowers_df.petal_length,bins=np.arange(2,5,0.25));

# %%
import numpy as np

# %%
plt.hist(flowers_df.sepal_width,bins=np.arange(2,5,0.25));

# %%
plt.hist(flowers_df.sepal_width,bins=[1,3,4,5]);

# %%
setosa_df= flowers_df[flowers_df.species=='setosa']
versicolor_df= flowers_df[flowers_df.species=='versicolor']
virginca_df= flowers_df[flowers_df.species=='virginica']

# %%
plt.hist(setosa_df.sepal_width,alpha=0.4,bins=np.arange(2,5,0.25));
plt.hist(versicolor_df.sepal_width,alpha=0.4,bins=np.arange(2,5,0.25));

# %%
plt.hist([setosa_df.sepal_width, versicolor_df.sepal_width,virginca_df.sepal_width],
         bins=np.arange(2,5,0.25),
         stacked=True);

# %%
sns.scatterplot(x=flowers_df.petal_length,y=flowers_df.petal_width);

# %%
sns.scatterplot(x=flowers_df.sepal_length,y=flowers_df.petal_length);

# %%
sns.scatterplot(x=flowers_df.petal_length,y=flowers_df.petal_width);

# %%
plt.hist(setosa_df.sepal_width,alpha=0.4,bins=np.arange(2,5,0.25));
plt.hist(virginca_df.sepal_width,alpha=0.4,bins=np.arange(2,5,0.25));

# %%
plt.hist(setosa_df.petal_width,alpha=0.4,bins=np.arange(2,5,0.25));
plt.hist(virginca_df.petal_width,alpha=0.4,bins=np.arange(2,5,0.25));

# %%
plt.plot(x,y, marker='D' ,c='k' ,ls='--', lw=2, ms=8, mew=2, mec='navy')

plt.plot(y,z, marker='o', ls='-',lw='3' ,ms=10, alpha=.5 )

plt.xlabel('x')
plt.ylabel('y')
    
plt.title(['z'])
plt.legend(['y']);

# %%
plt.plot(z,y, marker='D' ,c='k' ,ls='--', lw=2, ms=8, mew=2, mec='navy')

plt.plot(x,z, marker='o', ls='-',lw='3' ,ms=10, alpha=.5 )

plt.xlabel('x')
plt.ylabel('y')
    
plt.title(['z'])
plt.legend(['y']);

# %%
plt.plot(x,y, marker=',' ,c='k' ,ls='-', lw=2, ms=8, mew=2, mec='navy')

plt.plot(y,z, marker='o', ls='--',lw='3' ,ms=10, alpha=.5 )

plt.xlabel('x')
plt.ylabel('y')
    
plt.title(['z'])
plt.legend(['y']);

# %%
plt.plot(z,y, marker='8' ,c='k' ,ls='-.', lw=2, ms=8, mew=2, mec='navy')

plt.plot(x,y, marker='s', ls='-',lw='3' ,ms=10, alpha=.5 )

plt.xlabel('x')
plt.ylabel('y')
    
plt.title(['z'])
plt.legend(['y']);

# %%
plt.plot(x,y, marker='v' ,c='c' ,ls='--', lw=2, ms=8, mew=2, mec='navy')

plt.plot(y,z, marker='o', ls='-',lw='3' ,ms=10, alpha=.5 )

plt.xlabel('x')
plt.ylabel('y')
    
plt.title(['z'])
plt.legend(['y']);

# %%
plt.title('Sepal Dimension')
sns.scatterplot(x='petal_length',
                y='petal_width',
                hue='species',
               s=300,
              data=flowers_df );

# %%
plt.title('Sepal Dimension')
sns.scatterplot(x='sepal_length',
                y='petal_length',
                hue='species',
               s=300,
              data=flowers_df );

# %%
plt.title('Sepal Dimension')
sns.scatterplot(x='petal_width',
                y='sepal_width',
                hue='species',
               s=300,
              data=flowers_df );

# %%
plt.hist([setosa_df.petal_width, versicolor_df.petal_width,virginca_df.petal_width],
         bins=np.arange(2,5,0.25),
         stacked=True);

# %%
plt.hist([setosa_df.petal_width, versicolor_df.sepal_length,virginca_df.petal_length],
         bins=np.arange(2,5,0.25),
         stacked=True);

# %%
years=range(2000,2005)
apples=[0.35,0.6,0.9,0.65,0.8]
oranges=[0,4,0.8,0.9,0.7,0.6]

# %%
plt.bar (years, oranges);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 plt.bar (years, oranges)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:2439, in bar(x, height, width, bottom, align, data, **kwargs)
#    2435 @_copy_docstring_and_deprecators(Axes.bar)
#    2436 def bar(
#    2437         x, height, width=0.8, bottom=None, *, align='center',
#    2438         data=None, **kwargs):
# -> 2439     return gca().bar(
#    2440         x, height, width=width, bottom=bottom, align=align,
#    2441         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\__init__.py:1446, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1443 @functools.wraps(func)
#    1444 def inner(ax, *args, data=None, **kwargs):
#    1445     if data is None:
# ...

# %%
tips_df=sns.load_dataset("tips")

# %%
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.barplot(x='day',y='total_bill',data=tips_df,hue="sex");

# %%
tips_df.groupby('day').total_bill.mean()
# Out:
# day
# Thur    17.682742
# Fri     17.151579
# Sat     20.441379
# Sun     21.410000
# Name: total_bill, dtype: float64

# %%
tips_df.groupby('day').total_bill.count()
# Out:
# day
# Thur    62
# Fri     19
# Sat     87
# Sun     76
# Name: total_bill, dtype: int64

# %%
tips_df.groupby('day').time.count()
# Out:
# day
# Thur    62
# Fri     19
# Sat     87
# Sun     76
# Name: time, dtype: int64

# %%
tips_df.groupby('day').total_bill.describe()
# Out:
#       count       mean       std   min      25%    50%      75%    max
# day
# Thur   62.0  17.682742  7.886170  7.51  12.4425  16.20  20.1550  43.11
# Fri    19.0  17.151579  8.302660  5.75  12.0950  15.38  21.7500  40.17
# Sat    87.0  20.441379  9.480419  3.07  13.9050  18.24  24.7400  50.81
# Sun    76.0  21.410000  8.832122  7.25  14.9875  19.63  25.5975  48.17

# %%
tips_df.groupby('day').smoker.count()
# Out:
# day
# Thur    62
# Fri     19
# Sat     87
# Sun     76
# Name: smoker, dtype: int64

# %%
sns.barplot(x='total_bill',y='day',data=tips_df,hue="sex");

# %%
import seaborn as sns
import pandas as pd
flights_df=sns.load_dataset("flights").pivot(index="month",columns="year",values="passengers");

# %%
flights_df
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
plt.title("number of passengers(1000s)")
sns.heatmap(flights_df);

# %%
plt.title("number of passengers(1000s)")
sns.heatmap(flights_df,fmt="d",annot=True, cmap='Blues');

# %%
from urllib.request import urlretrieve

# %%
urlretrieve('https://i.imgur.com/SkPbq.jpg' , 'chart.jpg');

# %%
from PIL import Image

# %%
img=Image.open('chart.jpg')

# %%
img_array=np.array(img)

# %%
img_array.shape
# Out:
# (481, 640, 3)

# %%
plt.imshow(img);

# %%
plt.grid(False)
plt.axis('off')
plt.imshow(img_array[125:325,105:305]);

# %%
sns.pairplot(flowers_df,hue='species');
# Out:
# C:\Users\sudhar\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(tips_df,hue='sex');
# Out:
# C:\Users\sudhar\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
